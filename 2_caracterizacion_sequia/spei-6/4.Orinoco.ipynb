# %%
# ============================================================================
# Drought characterization — Orinoco basin
# Method: Run Theory (Yevjevich, 1967)
# Index: SPEI-6
# Metrics: Frequency, Duration (median), Severity (median)
# Definition: event starts when SPEI < -1 for >= 2 consecutive months
#             event ends when SPEI >= 0
# Reference: Spinoni et al. (2014), Tabari et al. (2021)
# Scenarios: Historical (1985-2014), SSP126 (2041-2070), SSP585 (2041-2070)
# Models: MPI-ESM1-2-HR, UKESM1-0-LL, GFDL-ESM4, IPSL-CM6A-LR, MRI-ESM2-0
# ============================================================================

import os
import numpy as np
import xarray as xr
import netCDF4 as nc
from pathlib import Path

# --- CONFIGURATION ---
models    = ["MPI-ESM1-2-HR", "UKESM1-0-LL", "GFDL-ESM4", "IPSL-CM6A-LR", "MRI-ESM2-0"]
scenarios = ["historical", "ssp126", "ssp585"]
basin     = "orinoco"

path_in  = "/data/brussel/vo/000/bvo00033/vsc11346/SPEI_R/3.outputs_SPEI_R/5.baseline_106_6ac_OF/Orinoco/"
path_out = "/data/brussel/vo/000/bvo00033/vsc11346/SPEI_R/7.Caracterizacion_sequia/SPEI-6/2.Outputs/Orinoco/"


# ============================================================================
# FUNCTION: Calculate drought metrics for a single time series
# ============================================================================
def calc_drought_metrics(spei_ts):
    n           = len(spei_ts)
    in_event    = False
    consec_neg  = 0
    event_start = None
    durations   = []
    severities  = []

    for t in range(n):
        val = spei_ts[t]

        if np.isnan(val):
            in_event   = False
            consec_neg = 0
            continue

        if not in_event:
            if val < -1:
                consec_neg += 1
                if consec_neg >= 2:
                    in_event    = True
                    event_start = t - 1
            else:
                consec_neg = 0
        else:
            if val >= 0:
                duration = (t - 1) - event_start + 1
                severity = np.sum(np.abs(spei_ts[event_start:t]))
                durations.append(duration)
                severities.append(severity)
                in_event   = False
                consec_neg = 0

    if in_event:
        duration = (n - 1) - event_start + 1
        severity = np.sum(np.abs(spei_ts[event_start:n]))
        durations.append(duration)
        severities.append(severity)

    frequency = len(durations)
    if frequency == 0:
        return frequency, np.nan, np.nan

    return frequency, np.median(durations), np.median(severities)


# ============================================================================
# FUNCTION: Save drought metrics as NetCDF
# ============================================================================
def save_netcdf(freq_grid, dur_grid, sev_grid, lon, lat,
                basin, scenario, model, output_dir):
    output_file = f"{output_dir}drought_metrics_{basin}_{scenario}_{model}.nc"
    ds_out      = nc.Dataset(output_file, "w", format="NETCDF4")

    ds_out.createDimension("lat", len(lat))
    ds_out.createDimension("lon", len(lon))

    lat_var       = ds_out.createVariable("lat", "f4", ("lat",))
    lat_var.units = "degrees_north"
    lat_var[:]    = lat

    lon_var       = ds_out.createVariable("lon", "f4", ("lon",))
    lon_var.units = "degrees_east"
    lon_var[:]    = lon

    freq_save = np.where(np.isnan(freq_grid), -9999, freq_grid)
    dur_save  = np.where(np.isnan(dur_grid),  -9999, dur_grid)
    sev_save  = np.where(np.isnan(sev_grid),  -9999, sev_grid)

    freq_var           = ds_out.createVariable("frequency", "f4", ("lat", "lon"),
                                                fill_value=-9999)
    freq_var.units     = "count"
    freq_var.long_name = "Number of drought events"
    freq_var[:]        = freq_save

    dur_var           = ds_out.createVariable("duration", "f4", ("lat", "lon"),
                                               fill_value=-9999)
    dur_var.units     = "months"
    dur_var.long_name = "Median drought duration"
    dur_var[:]        = dur_save

    sev_var           = ds_out.createVariable("severity", "f4", ("lat", "lon"),
                                               fill_value=-9999)
    sev_var.units     = "-"
    sev_var.long_name = "Median drought severity (sum of |SPEI| per event)"
    sev_var[:]        = sev_save

    ds_out.description = (f"Drought characteristics — {basin} basin, "
                          f"{scenario}, {model}. "
                          f"Run theory (Yevjevich 1967): "
                          f"start SPEI < -1 for >= 2 months, end SPEI >= 0.")
    ds_out.index       = "SPEI-6"
    ds_out.basin       = basin
    ds_out.scenario    = scenario
    ds_out.model       = model

    ds_out.close()
    print(f"    Saved: {output_file}")


# ============================================================================
# FUNCTION: Calculate ensemble median across 5 models
# ============================================================================
def calc_ensemble(basin, scenario, models, output_dir):
    freq_stack = []
    dur_stack  = []
    sev_stack  = []

    for model in models:
        nc_file = f"{output_dir}drought_metrics_{basin}_{scenario}_{model}.nc"
        ds      = xr.open_dataset(nc_file)

        freq = np.where(ds["frequency"].values == -9999, np.nan, ds["frequency"].values.astype(float))
        dur  = np.where(ds["duration"].values  == -9999, np.nan, ds["duration"].values.astype(float))
        sev  = np.where(ds["severity"].values  == -9999, np.nan, ds["severity"].values.astype(float))

        freq_stack.append(freq)
        dur_stack.append(dur)
        sev_stack.append(sev)

        lon = ds["lon"].values
        lat = ds["lat"].values
        ds.close()

    freq_ensemble = np.nanmedian(np.stack(freq_stack, axis=0), axis=0)
    dur_ensemble  = np.nanmedian(np.stack(dur_stack,  axis=0), axis=0)
    sev_ensemble  = np.nanmedian(np.stack(sev_stack,  axis=0), axis=0)

    save_netcdf(freq_ensemble, dur_ensemble, sev_ensemble,
                lon, lat, basin, scenario, "ensemble", output_dir)

    print(f"\n  Ensemble summary — {scenario}:")
    for name, grid in [("FREQUENCY", freq_ensemble),
                       ("DURATION",  dur_ensemble),
                       ("SEVERITY",  sev_ensemble)]:
        valid = grid[~np.isnan(grid)]
        print(f"    {name}: min={valid.min():.2f}, "
              f"max={valid.max():.2f}, "
              f"median={np.median(valid):.2f}")


# ============================================================================
# MAIN LOOP — SCENARIOS x MODELS
# ============================================================================
for scenario in scenarios:

    out_dir = f"{path_out}{scenario}/"
    Path(out_dir).mkdir(parents=True, exist_ok=True)

    print(f"\n{'='*60}")
    print(f"SCENARIO: {scenario.upper()} | BASIN: {basin.upper()}")
    print(f"{'='*60}")

    for model in models:

        print(f"\n  Processing: {model}")

        nc_file = f"{path_in}{scenario}/spei6_{basin}_{scenario}_{model}.nc"
        ds      = xr.open_dataset(nc_file)
        spei    = ds["SPEI_6"].values
        lon     = ds["lon"].values
        lat     = ds["lat"].values
        dims    = ds["SPEI_6"].dims
        ds.close()

        spei = np.where(spei == -9999, np.nan, spei)

        if dims[0] == "time":
            spei = np.transpose(spei, (1, 2, 0))

        n_lon, n_lat, _ = spei.shape

        freq_grid = np.full((n_lon, n_lat), np.nan)
        dur_grid  = np.full((n_lon, n_lat), np.nan)
        sev_grid  = np.full((n_lon, n_lat), np.nan)

        for i in range(n_lon):
            for j in range(n_lat):
                ts = spei[i, j, :]
                if np.all(np.isnan(ts)):
                    continue
                (freq_grid[i, j],
                 dur_grid[i, j],
                 sev_grid[i, j]) = calc_drought_metrics(ts)

        for name, grid in [("FREQUENCY", freq_grid),
                           ("DURATION",  dur_grid),
                           ("SEVERITY",  sev_grid)]:
            valid = grid[~np.isnan(grid)]
            print(f"    {name}: min={valid.min():.2f}, "
                  f"max={valid.max():.2f}, "
                  f"median={np.median(valid):.2f}")

        save_netcdf(freq_grid, dur_grid, sev_grid,
                    lon, lat, basin, scenario, model, out_dir)

    print(f"\n  Computing ensemble median — {scenario}")
    calc_ensemble(basin, scenario, models, out_dir)


print(f"\n{'='*60}")
print(f"COMPLETED — Orinoco basin, 5 models, 3 scenarios")
print(f"Output: {path_out}")
print(f"{'='*60}")
# Out:
# ============================================================
# SCENARIO: HISTORICAL | BASIN: ORINOCO
# ============================================================
#
#   Processing: MPI-ESM1-2-HR
#     FREQUENCY: min=4.00, max=17.00, median=9.00
#     DURATION: min=4.00, max=29.00, median=9.00
#     SEVERITY: min=4.11, max=38.39, median=10.33
#     Saved: /data/brussel/vo/000/bvo00033/vsc11346/SPEI_R/7.Caracterizacion_sequia/SPEI-6/2.Outputs/Orinoco/historical/drought_metrics_orinoco_historical_MPI-ESM1-2-HR.nc
#
#   Processing: UKESM1-0-LL
#     FREQUENCY: min=4.00, max=16.00, median=8.00
#     DURATION: min=5.00, max=23.50, median=11.00
#     SEVERITY: min=4.54, max=27.27, median=11.39
#     Saved: /data/brussel/vo/000/bvo00033/vsc11346/SPEI_R/7.Caracterizacion_sequia/SPEI-6/2.Outputs/Orinoco/historical/drought_metrics_orinoco_historical_UKESM1-0-LL.nc
#
#   Processing: GFDL-ESM4
#     FREQUENCY: min=4.00, max=12.00, median=8.00
#     DURATION: min=6.00, max=25.00, median=11.50
#     SEVERITY: min=5.25, max=27.38, median=12.47
#     Saved: /data/brussel/vo/000/bvo00033/vsc11346/SPEI_R/7.Caracterizacion_sequia/SPEI-6/2.Outputs/Orinoco/historical/drought_metrics_orinoco_historical_GFDL-ESM4.nc
#
#   Processing: IPSL-CM6A-LR
#     FREQUENCY: min=4.00, max=15.00, median=7.00
#     DURATION: min=5.00, max=23.00, median=11.00
#     SEVERITY: min=4.77, max=25.86, median=12.15
#     Saved: /data/brussel/vo/000/bvo00033/vsc11346/SPEI_R/7.Caracterizacion_sequia/SPEI-6/2.Outputs/Orinoco/historical/drought_metrics_orinoco_historical_IPSL-CM6A-LR.nc
#
#   Processing: MRI-ESM2-0
#     FREQUENCY: min=4.00, max=15.00, median=9.00
#     DURATION: min=4.50, max=16.50, median=9.00
#     SEVERITY: min=4.71, max=18.46, median=9.96
#     Saved: /data/brussel/vo/000/bvo00033/vsc11346/SPEI_R/7.Caracterizacion_sequia/SPEI-6/2.Outputs/Orinoco/historical/drought_metrics_orinoco_historical_MRI-ESM2-0.nc
#
#   Computing ensemble median — historical
#     Saved: /data/brussel/vo/000/bvo00033/vsc11346/SPEI_R/7.Caracterizacion_sequia/SPEI-6/2.Outputs/Orinoco/historical/drought_metrics_orinoco_historical_ensemble.nc
#
#   Ensemble summary — historical:
#     FREQUENCY: min=5.00, max=12.00, median=8.00
#     DURATION: min=6.50, max=18.00, median=10.00
#     SEVERITY: min=7.19, max=20.12, median=11.26
#
# ============================================================
# SCENARIO: SSP126 | BASIN: ORINOCO
# ============================================================
#
#   Processing: MPI-ESM1-2-HR
# /tmp/ipykernel_1983992/1893818756.py:155: RuntimeWarning: All-NaN slice encountered
#   freq_ensemble = np.nanmedian(np.stack(freq_stack, axis=0), axis=0)
# /tmp/ipykernel_1983992/1893818756.py:156: RuntimeWarning: All-NaN slice encountered
#   dur_ensemble  = np.nanmedian(np.stack(dur_stack,  axis=0), axis=0)
# /tmp/ipykernel_1983992/1893818756.py:157: RuntimeWarning: All-NaN slice encountered
#   sev_ensemble  = np.nanmedian(np.stack(sev_stack,  axis=0), axis=0)
#     FREQUENCY: min=5.00, max=18.00, median=10.00
#     DURATION: min=5.00, max=26.00, median=9.00
#     SEVERITY: min=4.48, max=27.43, median=10.06
#     Saved: /data/brussel/vo/000/bvo00033/vsc11346/SPEI_R/7.Caracterizacion_sequia/SPEI-6/2.Outputs/Orinoco/ssp126/drought_metrics_orinoco_ssp126_MPI-ESM1-2-HR.nc
#
#   Processing: UKESM1-0-LL
#     FREQUENCY: min=6.00, max=18.00, median=13.00
#     DURATION: min=4.00, max=19.00, median=9.00
#     SEVERITY: min=5.92, max=22.80, median=11.55
#     Saved: /data/brussel/vo/000/bvo00033/vsc11346/SPEI_R/7.Caracterizacion_sequia/SPEI-6/2.Outputs/Orinoco/ssp126/drought_metrics_orinoco_ssp126_UKESM1-0-LL.nc
#
#   Processing: GFDL-ESM4
#     FREQUENCY: min=5.00, max=15.00, median=10.00
#     DURATION: min=5.00, max=28.00, median=11.00
#     SEVERITY: min=4.34, max=28.39, median=11.83
#     Saved: /data/brussel/vo/000/bvo00033/vsc11346/SPEI_R/7.Caracterizacion_sequia/SPEI-6/2.Outputs/Orinoco/ssp126/drought_metrics_orinoco_ssp126_GFDL-ESM4.nc
#
#   Processing: IPSL-CM6A-LR
#     FREQUENCY: min=5.00, max=15.00, median=10.00
#     DURATION: min=6.00, max=21.50, median=13.00
#     SEVERITY: min=5.88, max=28.75, median=15.29
#     Saved: /data/brussel/vo/000/bvo00033/vsc11346/SPEI_R/7.Caracterizacion_sequia/SPEI-6/2.Outputs/Orinoco/ssp126/drought_metrics_orinoco_ssp126_IPSL-CM6A-LR.nc
#
#   Processing: MRI-ESM2-0
#     FREQUENCY: min=1.00, max=15.00, median=10.00
#     DURATION: min=3.00, max=29.00, median=7.50
#     SEVERITY: min=2.80, max=30.41, median=9.00
#     Saved: /data/brussel/vo/000/bvo00033/vsc11346/SPEI_R/7.Caracterizacion_sequia/SPEI-6/2.Outputs/Orinoco/ssp126/drought_metrics_orinoco_ssp126_MRI-ESM2-0.nc
#
#   Computing ensemble median — ssp126
#     Saved: /data/brussel/vo/000/bvo00033/vsc11346/SPEI_R/7.Caracterizacion_sequia/SPEI-6/2.Outputs/Orinoco/ssp126/drought_metrics_orinoco_ssp126_ensemble.nc
#
#   Ensemble summary — ssp126:
#     FREQUENCY: min=8.00, max=14.00, median=10.00
#     DURATION: min=6.00, max=18.00, median=10.00
#     SEVERITY: min=6.72, max=21.15, median=11.39
#
# ============================================================
# SCENARIO: SSP585 | BASIN: ORINOCO
# ============================================================
#
#   Processing: MPI-ESM1-2-HR
# /tmp/ipykernel_1983992/1893818756.py:155: RuntimeWarning: All-NaN slice encountered
#   freq_ensemble = np.nanmedian(np.stack(freq_stack, axis=0), axis=0)
# /tmp/ipykernel_1983992/1893818756.py:156: RuntimeWarning: All-NaN slice encountered
#   dur_ensemble  = np.nanmedian(np.stack(dur_stack,  axis=0), axis=0)
# /tmp/ipykernel_1983992/1893818756.py:157: RuntimeWarning: All-NaN slice encountered
#   sev_ensemble  = np.nanmedian(np.stack(sev_stack,  axis=0), axis=0)
#     FREQUENCY: min=5.00, max=17.00, median=10.00
#     DURATION: min=6.00, max=36.00, median=11.00
#     SEVERITY: min=5.42, max=46.67, median=14.10
#     Saved: /data/brussel/vo/000/bvo00033/vsc11346/SPEI_R/7.Caracterizacion_sequia/SPEI-6/2.Outputs/Orinoco/ssp585/drought_metrics_orinoco_ssp585_MPI-ESM1-2-HR.nc
#
#   Processing: UKESM1-0-LL
#     FREQUENCY: min=3.00, max=18.00, median=10.00
#     DURATION: min=4.00, max=110.00, median=18.00
#     SEVERITY: min=4.49, max=119.20, median=19.59
#     Saved: /data/brussel/vo/000/bvo00033/vsc11346/SPEI_R/7.Caracterizacion_sequia/SPEI-6/2.Outputs/Orinoco/ssp585/drought_metrics_orinoco_ssp585_UKESM1-0-LL.nc
#
#   Processing: GFDL-ESM4
#     FREQUENCY: min=7.00, max=18.00, median=12.00
#     DURATION: min=6.00, max=28.00, median=10.00
#     SEVERITY: min=5.80, max=33.11, median=12.71
#     Saved: /data/brussel/vo/000/bvo00033/vsc11346/SPEI_R/7.Caracterizacion_sequia/SPEI-6/2.Outputs/Orinoco/ssp585/drought_metrics_orinoco_ssp585_GFDL-ESM4.nc
#
#   Processing: IPSL-CM6A-LR
#     FREQUENCY: min=2.00, max=18.00, median=10.00
#     DURATION: min=5.00, max=145.00, median=18.00
#     SEVERITY: min=6.66, max=179.49, median=21.78
#     Saved: /data/brussel/vo/000/bvo00033/vsc11346/SPEI_R/7.Caracterizacion_sequia/SPEI-6/2.Outputs/Orinoco/ssp585/drought_metrics_orinoco_ssp585_IPSL-CM6A-LR.nc
#
#   Processing: MRI-ESM2-0
#     FREQUENCY: min=6.00, max=21.00, median=12.00
#     DURATION: min=5.00, max=21.50, median=12.00
#     SEVERITY: min=4.83, max=29.49, median=15.06
#     Saved: /data/brussel/vo/000/bvo00033/vsc11346/SPEI_R/7.Caracterizacion_sequia/SPEI-6/2.Outputs/Orinoco/ssp585/drought_metrics_orinoco_ssp585_MRI-ESM2-0.nc
#
#   Computing ensemble median — ssp585
#     Saved: /data/brussel/vo/000/bvo00033/vsc11346/SPEI_R/7.Caracterizacion_sequia/SPEI-6/2.Outputs/Orinoco/ssp585/drought_metrics_orinoco_ssp585_ensemble.nc
#
#   Ensemble summary — ssp585:
#     FREQUENCY: min=5.00, max=15.00, median=11.00
#     DURATION: min=6.00, max=29.00, median=13.00
#     SEVERITY: min=7.00, max=31.20, median=15.76
#
# ============================================================
# COMPLETED — Orinoco basin, 5 models, 3 scenarios
# Output: /data/brussel/vo/000/bvo00033/vsc11346/SPEI_R/7.Caracterizacion_sequia/SPEI-6/2.Outputs/Orinoco/
# ============================================================
# /tmp/ipykernel_1983992/1893818756.py:155: RuntimeWarning: All-NaN slice encountered
#   freq_ensemble = np.nanmedian(np.stack(freq_stack, axis=0), axis=0)
# /tmp/ipykernel_1983992/1893818756.py:156: RuntimeWarning: All-NaN slice encountered
#   dur_ensemble  = np.nanmedian(np.stack(dur_stack,  axis=0), axis=0)
# /tmp/ipykernel_1983992/1893818756.py:157: RuntimeWarning: All-NaN slice encountered
#   sev_ensemble  = np.nanmedian(np.stack(sev_stack,  axis=0), axis=0)

# %%
# ============================================================================
# Verification — Orinoco basin — SPEI-6
# ============================================================================

import numpy as np
import xarray as xr
from pathlib import Path

path_out  = "/data/brussel/vo/000/bvo00033/vsc11346/SPEI_R/7.Caracterizacion_sequia/SPEI-6/2.Outputs/Orinoco/"
models    = ["MPI-ESM1-2-HR", "UKESM1-0-LL", "GFDL-ESM4", "IPSL-CM6A-LR", "MRI-ESM2-0", "ensemble"]
scenarios = ["historical", "ssp126", "ssp585"]
basin     = "orinoco"

print("=" * 60)
print("NETCDF VERIFICATION — Orinoco basin — SPEI-6")
print("=" * 60)

all_ok = True

for scenario in scenarios:
    print(f"\n--- {scenario.upper()} ---")
    for model in models:
        nc_file = Path(f"{path_out}{scenario}/drought_metrics_{basin}_{scenario}_{model}.nc")

        if not nc_file.exists():
            print(f"  ❌ MISSING: {nc_file.name}")
            all_ok = False
            continue

        ds   = xr.open_dataset(nc_file)
        freq = np.where(ds["frequency"].values == -9999, np.nan, ds["frequency"].values.astype(float))
        dur  = np.where(ds["duration"].values  == -9999, np.nan, ds["duration"].values.astype(float))
        sev  = np.where(ds["severity"].values  == -9999, np.nan, ds["severity"].values.astype(float))
        ds.close()

        n_valid   = np.sum(~np.isnan(freq))
        shape_ok  = freq.ndim == 2
        pixels_ok = (np.sum(~np.isnan(freq)) == np.sum(~np.isnan(dur)) == np.sum(~np.isnan(sev)))
        values_ok = (np.all(freq[~np.isnan(freq)] >= 0) and
                     np.all(dur[~np.isnan(dur)]   >= 0) and
                     np.all(sev[~np.isnan(sev)]   >= 0))
        no_inf    = not (np.any(np.isinf(freq)) or np.any(np.isinf(dur)) or np.any(np.isinf(sev)))

        status = "✅" if (shape_ok and pixels_ok and values_ok and no_inf) else "❌"
        if status == "❌":
            all_ok = False

        print(f"  {status} {model}")
        print(f"       Shape: {freq.shape} | Valid pixels: {n_valid} | "
              f"Freq=[{freq[~np.isnan(freq)].min():.1f},{freq[~np.isnan(freq)].max():.1f}] | "
              f"Dur=[{dur[~np.isnan(dur)].min():.1f},{dur[~np.isnan(dur)].max():.1f}] | "
              f"Sev=[{sev[~np.isnan(sev)].min():.2f},{sev[~np.isnan(sev)].max():.2f}]")

print(f"\n{'='*60}")
print("✅ ALL FILES VERIFIED — SPEI-6" if all_ok else "❌ SOME FILES HAVE ISSUES")
print(f"{'='*60}")
# Out:
# ============================================================
# NETCDF VERIFICATION — Orinoco basin — SPEI-6
# ============================================================
#
# --- HISTORICAL ---
#   ✅ MPI-ESM1-2-HR
#        Shape: (22, 53) | Valid pixels: 766 | Freq=[4.0,17.0] | Dur=[4.0,29.0] | Sev=[4.11,38.39]
#   ✅ UKESM1-0-LL
#        Shape: (22, 53) | Valid pixels: 766 | Freq=[4.0,16.0] | Dur=[5.0,23.5] | Sev=[4.54,27.27]
#   ✅ GFDL-ESM4
#        Shape: (22, 53) | Valid pixels: 766 | Freq=[4.0,12.0] | Dur=[6.0,25.0] | Sev=[5.25,27.38]
#   ✅ IPSL-CM6A-LR
#        Shape: (22, 53) | Valid pixels: 766 | Freq=[4.0,15.0] | Dur=[5.0,23.0] | Sev=[4.77,25.86]
#   ✅ MRI-ESM2-0
#        Shape: (22, 53) | Valid pixels: 766 | Freq=[4.0,15.0] | Dur=[4.5,16.5] | Sev=[4.71,18.46]
#   ✅ ensemble
#        Shape: (22, 53) | Valid pixels: 766 | Freq=[5.0,12.0] | Dur=[6.5,18.0] | Sev=[7.19,20.12]
#
# --- SSP126 ---
#   ✅ MPI-ESM1-2-HR
#        Shape: (22, 53) | Valid pixels: 766 | Freq=[5.0,18.0] | Dur=[5.0,26.0] | Sev=[4.48,27.43]
#   ✅ UKESM1-0-LL
#        Shape: (22, 53) | Valid pixels: 766 | Freq=[6.0,18.0] | Dur=[4.0,19.0] | Sev=[5.92,22.80]
#   ✅ GFDL-ESM4
#        Shape: (22, 53) | Valid pixels: 766 | Freq=[5.0,15.0] | Dur=[5.0,28.0] | Sev=[4.34,28.39]
#   ✅ IPSL-CM6A-LR
#        Shape: (22, 53) | Valid pixels: 766 | Freq=[5.0,15.0] | Dur=[6.0,21.5] | Sev=[5.88,28.75]
#   ✅ MRI-ESM2-0
#        Shape: (22, 53) | Valid pixels: 766 | Freq=[1.0,15.0] | Dur=[3.0,29.0] | Sev=[2.80,30.41]
#   ✅ ensemble
#        Shape: (22, 53) | Valid pixels: 766 | Freq=[8.0,14.0] | Dur=[6.0,18.0] | Sev=[6.72,21.15]
#
# --- SSP585 ---
#   ✅ MPI-ESM1-2-HR
#        Shape: (22, 53) | Valid pixels: 766 | Freq=[5.0,17.0] | Dur=[6.0,36.0] | Sev=[5.42,46.67]
#   ✅ UKESM1-0-LL
#        Shape: (22, 53) | Valid pixels: 766 | Freq=[3.0,18.0] | Dur=[4.0,110.0] | Sev=[4.49,119.20]
#   ✅ GFDL-ESM4
#        Shape: (22, 53) | Valid pixels: 766 | Freq=[7.0,18.0] | Dur=[6.0,28.0] | Sev=[5.80,33.11]
#   ✅ IPSL-CM6A-LR
#        Shape: (22, 53) | Valid pixels: 766 | Freq=[2.0,18.0] | Dur=[5.0,145.0] | Sev=[6.66,179.49]
#   ✅ MRI-ESM2-0
#        Shape: (22, 53) | Valid pixels: 766 | Freq=[6.0,21.0] | Dur=[5.0,21.5] | Sev=[4.83,29.49]
#   ✅ ensemble
#        Shape: (22, 53) | Valid pixels: 766 | Freq=[5.0,15.0] | Dur=[6.0,29.0] | Sev=[7.00,31.20]
#
# ============================================================
# ✅ ALL FILES VERIFIED — SPEI-6
# ============================================================
