# %%
# ============================================================================
# Drought characterization — Tocantins basin
# Method: Run Theory (Yevjevich, 1967)
# Index: SPEI-12
# Metrics: Frequency, Duration (median), Severity (median)
# Definition: event starts when SPEI < -1 for >= 2 consecutive months
#             event ends when SPEI >= 0
# Reference: Spinoni et al. (2014), Tabari et al. (2021)
# Scenarios: Historical (1985-2014), SSP126 (2041-2070), SSP585 (2041-2070)
# Models: MPI-ESM1-2-HR, UKESM1-0-LL, GFDL-ESM4, IPSL-CM6A-LR, MRI-ESM2-0
# ============================================================================

import os
import numpy as np
import xarray as xr
import netCDF4 as nc
from pathlib import Path

# --- CONFIGURATION ---
models    = ["MPI-ESM1-2-HR", "UKESM1-0-LL", "GFDL-ESM4", "IPSL-CM6A-LR", "MRI-ESM2-0"]
scenarios = ["historical", "ssp126", "ssp585"]
basin     = "tocantins"

path_in  = "/data/brussel/vo/000/bvo00033/vsc11346/SPEI_R/3.outputs_SPEI_R/4.baseline_106_12ac_OF/Tocantins/"
path_out = "/data/brussel/vo/000/bvo00033/vsc11346/SPEI_R/7.Caracterizacion_sequia/SPEI-12/2.Outputs/Tocantins/"


# ============================================================================
# FUNCTION: Calculate drought metrics for a single time series
# ============================================================================
def calc_drought_metrics(spei_ts):
    """
    Calculates drought frequency, duration and severity using run theory.

    Parameters:
        spei_ts (np.array): SPEI-12 time series for a single pixel

    Returns:
        frequency (int):         number of drought events
        duration_median (float): median duration across all events (months)
        severity_median (float): median severity across all events (sum of |SPEI|)

    Event definition:
        Start: SPEI < -1 for >= 2 consecutive months
        End:   SPEI >= 0
    """
    n           = len(spei_ts)
    in_event    = False
    consec_neg  = 0
    event_start = None
    durations   = []
    severities  = []

    for t in range(n):
        val = spei_ts[t]

        if np.isnan(val):
            in_event   = False
            consec_neg = 0
            continue

        if not in_event:
            if val < -1:
                consec_neg += 1
                if consec_neg >= 2:
                    in_event    = True
                    event_start = t - 1
            else:
                consec_neg = 0
        else:
            if val >= 0:
                duration = (t - 1) - event_start + 1
                severity = np.sum(np.abs(spei_ts[event_start:t]))
                durations.append(duration)
                severities.append(severity)
                in_event   = False
                consec_neg = 0

    # Handle event that does not close before end of series
    if in_event:
        duration = (n - 1) - event_start + 1
        severity = np.sum(np.abs(spei_ts[event_start:n]))
        durations.append(duration)
        severities.append(severity)

    frequency = len(durations)

    if frequency == 0:
        return frequency, np.nan, np.nan

    return frequency, np.median(durations), np.median(severities)


# ============================================================================
# FUNCTION: Save drought metrics as NetCDF
# ============================================================================
def save_netcdf(freq_grid, dur_grid, sev_grid, lon, lat,
                basin, scenario, model, output_dir):
    """
    Saves drought metrics (frequency, duration, severity) into a single NetCDF.
    Arrays are stored in (lat, lon) order following CF conventions.

    Parameters:
        freq_grid:  2D array (lat x lon) of drought frequency
        dur_grid:   2D array (lat x lon) of median drought duration
        sev_grid:   2D array (lat x lon) of median drought severity
        lon, lat:   coordinate arrays
        basin:      basin name string
        scenario:   scenario name string
        model:      model name string (or 'ensemble')
        output_dir: output directory path
    """
    output_file = f"{output_dir}drought_metrics_{basin}_{scenario}_{model}.nc"
    ds_out      = nc.Dataset(output_file, "w", format="NETCDF4")

    # Define dimensions — (lat, lon) following CF conventions
    ds_out.createDimension("lat", len(lat))
    ds_out.createDimension("lon", len(lon))

    # Define coordinate variables
    lat_var       = ds_out.createVariable("lat", "f4", ("lat",))
    lat_var.units = "degrees_north"
    lat_var[:]    = lat

    lon_var       = ds_out.createVariable("lon", "f4", ("lon",))
    lon_var.units = "degrees_east"
    lon_var[:]    = lon

    # Arrays are already (lat, lon) — no transpose needed
    freq_save = np.where(np.isnan(freq_grid), -9999, freq_grid)
    dur_save  = np.where(np.isnan(dur_grid),  -9999, dur_grid)
    sev_save  = np.where(np.isnan(sev_grid),  -9999, sev_grid)

    # Frequency variable
    freq_var           = ds_out.createVariable("frequency", "f4", ("lat", "lon"),
                                                fill_value=-9999)
    freq_var.units     = "count"
    freq_var.long_name = "Number of drought events"
    freq_var[:]        = freq_save

    # Duration variable
    dur_var           = ds_out.createVariable("duration", "f4", ("lat", "lon"),
                                               fill_value=-9999)
    dur_var.units     = "months"
    dur_var.long_name = "Median drought duration"
    dur_var[:]        = dur_save

    # Severity variable
    sev_var           = ds_out.createVariable("severity", "f4", ("lat", "lon"),
                                               fill_value=-9999)
    sev_var.units     = "-"
    sev_var.long_name = "Median drought severity (sum of |SPEI| per event)"
    sev_var[:]        = sev_save

    # Global attributes
    ds_out.description = (f"Drought characteristics — {basin} basin, "
                          f"{scenario}, {model}. "
                          f"Run theory (Yevjevich 1967): "
                          f"start SPEI < -1 for >= 2 months, end SPEI >= 0.")
    ds_out.index       = "SPEI-12"
    ds_out.basin       = basin
    ds_out.scenario    = scenario
    ds_out.model       = model

    ds_out.close()
    print(f"    Saved: {output_file}")


# ============================================================================
# FUNCTION: Calculate ensemble median across 5 models
# ============================================================================
def calc_ensemble(basin, scenario, models, output_dir):
    """
    Reads individual model NetCDFs and calculates pixel-wise median
    across all models for each metric.

    Saves result as drought_metrics_{basin}_{scenario}_ensemble.nc
    """
    freq_stack = []
    dur_stack  = []
    sev_stack  = []

    for model in models:
        nc_file = f"{output_dir}drought_metrics_{basin}_{scenario}_{model}.nc"
        ds      = xr.open_dataset(nc_file)

        freq = ds["frequency"].values.astype(float)
        dur  = ds["duration"].values.astype(float)
        sev  = ds["severity"].values.astype(float)

        # Replace fill values with NaN
        freq = np.where(freq == -9999, np.nan, freq)
        dur  = np.where(dur  == -9999, np.nan, dur)
        sev  = np.where(sev  == -9999, np.nan, sev)

        freq_stack.append(freq)
        dur_stack.append(dur)
        sev_stack.append(sev)

        lon = ds["lon"].values
        lat = ds["lat"].values
        ds.close()

    # Stack → shape (5, lat, lon) → pixel-wise median along model axis
    freq_ensemble = np.nanmedian(np.stack(freq_stack, axis=0), axis=0)
    dur_ensemble  = np.nanmedian(np.stack(dur_stack,  axis=0), axis=0)
    sev_ensemble  = np.nanmedian(np.stack(sev_stack,  axis=0), axis=0)

    # Arrays are already (lat, lon) — no transpose needed
    save_netcdf(freq_ensemble, dur_ensemble, sev_ensemble,
                lon, lat, basin, scenario, "ensemble", output_dir)

    # Print ensemble summary
    print(f"\n  Ensemble summary — {scenario}:")
    for name, grid in [("FREQUENCY", freq_ensemble),
                       ("DURATION",  dur_ensemble),
                       ("SEVERITY",  sev_ensemble)]:
        valid = grid[~np.isnan(grid)]
        print(f"    {name}: min={valid.min():.2f}, "
              f"max={valid.max():.2f}, "
              f"median={np.median(valid):.2f}")


# ============================================================================
# MAIN LOOP — SCENARIOS x MODELS
# ============================================================================
for scenario in scenarios:

    out_dir = f"{path_out}{scenario}/"
    Path(out_dir).mkdir(parents=True, exist_ok=True)

    print(f"\n{'='*60}")
    print(f"SCENARIO: {scenario.upper()} | BASIN: {basin.upper()}")
    print(f"{'='*60}")

    for model in models:

        print(f"\n  Processing: {model}")

        # Read SPEI-12 NetCDF
        nc_file = f"{path_in}{scenario}/spei12_{basin}_{scenario}_{model}.nc"
        ds      = xr.open_dataset(nc_file)
        spei    = ds["SPEI_12"].values
        lon     = ds["lon"].values
        lat     = ds["lat"].values
        dims    = ds["SPEI_12"].dims
        ds.close()

        # Replace fill values
        spei = np.where(spei == -9999, np.nan, spei)

        # Ensure (lon, lat, time) order
        if dims[0] == "time":
            spei = np.transpose(spei, (1, 2, 0))

        n_lon, n_lat, _ = spei.shape

        # Initialize output grids — shape (n_lon, n_lat)
        freq_grid = np.full((n_lon, n_lat), np.nan)
        dur_grid  = np.full((n_lon, n_lat), np.nan)
        sev_grid  = np.full((n_lon, n_lat), np.nan)

        # Pixel-by-pixel calculation
        for i in range(n_lon):
            for j in range(n_lat):
                ts = spei[i, j, :]
                if np.all(np.isnan(ts)):
                    continue
                (freq_grid[i, j],
                 dur_grid[i, j],
                 sev_grid[i, j]) = calc_drought_metrics(ts)

        # Print model summary
        for name, grid in [("FREQUENCY", freq_grid),
                           ("DURATION",  dur_grid),
                           ("SEVERITY",  sev_grid)]:
            valid = grid[~np.isnan(grid)]
            print(f"    {name}: min={valid.min():.2f}, "
                  f"max={valid.max():.2f}, "
                  f"median={np.median(valid):.2f}")

        # Save individual model NetCDF
        save_netcdf(freq_grid, dur_grid, sev_grid,
                    lon, lat, basin, scenario, model, out_dir)

    # Calculate and save ensemble median
    print(f"\n  Computing ensemble median — {scenario}")
    calc_ensemble(basin, scenario, models, out_dir)


print(f"\n{'='*60}")
print(f"COMPLETED — Tocantins basin, 5 models, 3 scenarios")
print(f"Output: {path_out}")
print(f"{'='*60}")
# Out:
# ============================================================
# SCENARIO: HISTORICAL | BASIN: TOCANTINS
# ============================================================
#
#   Processing: MPI-ESM1-2-HR
#     FREQUENCY: min=2.00, max=9.00, median=5.00
#     DURATION: min=6.00, max=44.00, median=16.50
#     SEVERITY: min=4.56, max=50.76, median=18.29
#     Saved: /data/brussel/vo/000/bvo00033/vsc11346/SPEI_R/7.Caracterizacion_sequia/SPEI-12/2.Outputs/Tocantins/historical/drought_metrics_tocantins_historical_MPI-ESM1-2-HR.nc
#
#   Processing: UKESM1-0-LL
#     FREQUENCY: min=3.00, max=10.00, median=6.00
#     DURATION: min=5.50, max=44.00, median=15.50
#     SEVERITY: min=4.23, max=45.81, median=16.34
#     Saved: /data/brussel/vo/000/bvo00033/vsc11346/SPEI_R/7.Caracterizacion_sequia/SPEI-12/2.Outputs/Tocantins/historical/drought_metrics_tocantins_historical_UKESM1-0-LL.nc
#
#   Processing: GFDL-ESM4
#     FREQUENCY: min=3.00, max=8.00, median=5.00
#     DURATION: min=11.00, max=36.50, median=19.00
#     SEVERITY: min=8.62, max=44.98, median=22.44
#     Saved: /data/brussel/vo/000/bvo00033/vsc11346/SPEI_R/7.Caracterizacion_sequia/SPEI-12/2.Outputs/Tocantins/historical/drought_metrics_tocantins_historical_GFDL-ESM4.nc
#
#   Processing: IPSL-CM6A-LR
#     FREQUENCY: min=2.00, max=8.00, median=6.00
#     DURATION: min=10.00, max=61.00, median=22.00
#     SEVERITY: min=8.94, max=65.58, median=24.50
#     Saved: /data/brussel/vo/000/bvo00033/vsc11346/SPEI_R/7.Caracterizacion_sequia/SPEI-12/2.Outputs/Tocantins/historical/drought_metrics_tocantins_historical_IPSL-CM6A-LR.nc
#
#   Processing: MRI-ESM2-0
#     FREQUENCY: min=2.00, max=9.00, median=5.00
#     DURATION: min=12.00, max=126.00, median=21.50
#     SEVERITY: min=6.95, max=111.22, median=24.68
#     Saved: /data/brussel/vo/000/bvo00033/vsc11346/SPEI_R/7.Caracterizacion_sequia/SPEI-12/2.Outputs/Tocantins/historical/drought_metrics_tocantins_historical_MRI-ESM2-0.nc
#
#   Computing ensemble median — historical
#     Saved: /data/brussel/vo/000/bvo00033/vsc11346/SPEI_R/7.Caracterizacion_sequia/SPEI-12/2.Outputs/Tocantins/historical/drought_metrics_tocantins_historical_ensemble.nc
#
#   Ensemble summary — historical:
#     FREQUENCY: min=4.00, max=7.00, median=6.00
#     DURATION: min=12.00, max=33.50, median=19.00
#     SEVERITY: min=12.66, max=42.36, median=20.89
#
# ============================================================
# SCENARIO: SSP126 | BASIN: TOCANTINS
# ============================================================
#
#   Processing: MPI-ESM1-2-HR
# /tmp/ipykernel_715602/3043205760.py:205: RuntimeWarning: All-NaN slice encountered
#   freq_ensemble = np.nanmedian(np.stack(freq_stack, axis=0), axis=0)
# /tmp/ipykernel_715602/3043205760.py:206: RuntimeWarning: All-NaN slice encountered
#   dur_ensemble  = np.nanmedian(np.stack(dur_stack,  axis=0), axis=0)
# /tmp/ipykernel_715602/3043205760.py:207: RuntimeWarning: All-NaN slice encountered
#   sev_ensemble  = np.nanmedian(np.stack(sev_stack,  axis=0), axis=0)
#     FREQUENCY: min=3.00, max=10.00, median=7.00
#     DURATION: min=11.00, max=36.00, median=20.00
#     SEVERITY: min=10.68, max=47.79, median=24.55
#     Saved: /data/brussel/vo/000/bvo00033/vsc11346/SPEI_R/7.Caracterizacion_sequia/SPEI-12/2.Outputs/Tocantins/ssp126/drought_metrics_tocantins_ssp126_MPI-ESM1-2-HR.nc
#
#   Processing: UKESM1-0-LL
#     FREQUENCY: min=3.00, max=9.00, median=6.00
#     DURATION: min=12.00, max=119.00, median=34.00
#     SEVERITY: min=11.62, max=130.69, median=41.51
#     Saved: /data/brussel/vo/000/bvo00033/vsc11346/SPEI_R/7.Caracterizacion_sequia/SPEI-12/2.Outputs/Tocantins/ssp126/drought_metrics_tocantins_ssp126_UKESM1-0-LL.nc
#
#   Processing: GFDL-ESM4
#     FREQUENCY: min=4.00, max=10.00, median=7.00
#     DURATION: min=9.00, max=47.00, median=23.25
#     SEVERITY: min=8.72, max=60.65, median=26.34
#     Saved: /data/brussel/vo/000/bvo00033/vsc11346/SPEI_R/7.Caracterizacion_sequia/SPEI-12/2.Outputs/Tocantins/ssp126/drought_metrics_tocantins_ssp126_GFDL-ESM4.nc
#
#   Processing: IPSL-CM6A-LR
#     FREQUENCY: min=4.00, max=10.00, median=7.00
#     DURATION: min=8.00, max=47.00, median=15.50
#     SEVERITY: min=7.05, max=51.04, median=19.69
#     Saved: /data/brussel/vo/000/bvo00033/vsc11346/SPEI_R/7.Caracterizacion_sequia/SPEI-12/2.Outputs/Tocantins/ssp126/drought_metrics_tocantins_ssp126_IPSL-CM6A-LR.nc
#
#   Processing: MRI-ESM2-0
#     FREQUENCY: min=3.00, max=10.00, median=6.00
#     DURATION: min=9.00, max=78.00, median=23.00
#     SEVERITY: min=7.78, max=89.91, median=27.67
#     Saved: /data/brussel/vo/000/bvo00033/vsc11346/SPEI_R/7.Caracterizacion_sequia/SPEI-12/2.Outputs/Tocantins/ssp126/drought_metrics_tocantins_ssp126_MRI-ESM2-0.nc
#
#   Computing ensemble median — ssp126
#     Saved: /data/brussel/vo/000/bvo00033/vsc11346/SPEI_R/7.Caracterizacion_sequia/SPEI-12/2.Outputs/Tocantins/ssp126/drought_metrics_tocantins_ssp126_ensemble.nc
#
#   Ensemble summary — ssp126:
#     FREQUENCY: min=4.00, max=9.00, median=6.00
#     DURATION: min=12.00, max=37.00, median=22.50
#     SEVERITY: min=14.97, max=47.58, median=26.61
#
# ============================================================
# SCENARIO: SSP585 | BASIN: TOCANTINS
# ============================================================
#
#   Processing: MPI-ESM1-2-HR
# /tmp/ipykernel_715602/3043205760.py:205: RuntimeWarning: All-NaN slice encountered
#   freq_ensemble = np.nanmedian(np.stack(freq_stack, axis=0), axis=0)
# /tmp/ipykernel_715602/3043205760.py:206: RuntimeWarning: All-NaN slice encountered
#   dur_ensemble  = np.nanmedian(np.stack(dur_stack,  axis=0), axis=0)
# /tmp/ipykernel_715602/3043205760.py:207: RuntimeWarning: All-NaN slice encountered
#   sev_ensemble  = np.nanmedian(np.stack(sev_stack,  axis=0), axis=0)
#     FREQUENCY: min=2.00, max=9.00, median=5.00
#     DURATION: min=10.00, max=153.50, median=35.00
#     SEVERITY: min=10.43, max=180.80, median=42.62
#     Saved: /data/brussel/vo/000/bvo00033/vsc11346/SPEI_R/7.Caracterizacion_sequia/SPEI-12/2.Outputs/Tocantins/ssp585/drought_metrics_tocantins_ssp585_MPI-ESM1-2-HR.nc
#
#   Processing: UKESM1-0-LL
#     FREQUENCY: min=2.00, max=8.00, median=4.00
#     DURATION: min=12.00, max=174.50, median=34.00
#     SEVERITY: min=13.67, max=190.75, median=36.19
#     Saved: /data/brussel/vo/000/bvo00033/vsc11346/SPEI_R/7.Caracterizacion_sequia/SPEI-12/2.Outputs/Tocantins/ssp585/drought_metrics_tocantins_ssp585_UKESM1-0-LL.nc
#
#   Processing: GFDL-ESM4
#     FREQUENCY: min=4.00, max=11.00, median=6.00
#     DURATION: min=11.00, max=89.00, median=27.00
#     SEVERITY: min=13.00, max=96.84, median=32.99
#     Saved: /data/brussel/vo/000/bvo00033/vsc11346/SPEI_R/7.Caracterizacion_sequia/SPEI-12/2.Outputs/Tocantins/ssp585/drought_metrics_tocantins_ssp585_GFDL-ESM4.nc
#
#   Processing: IPSL-CM6A-LR
#     FREQUENCY: min=3.00, max=9.00, median=6.00
#     DURATION: min=9.00, max=77.00, median=24.75
#     SEVERITY: min=9.88, max=95.37, median=28.86
#     Saved: /data/brussel/vo/000/bvo00033/vsc11346/SPEI_R/7.Caracterizacion_sequia/SPEI-12/2.Outputs/Tocantins/ssp585/drought_metrics_tocantins_ssp585_IPSL-CM6A-LR.nc
#
#   Processing: MRI-ESM2-0
#     FREQUENCY: min=2.00, max=11.00, median=7.00
#     DURATION: min=11.00, max=147.50, median=22.00
#     SEVERITY: min=11.55, max=167.61, median=24.95
#     Saved: /data/brussel/vo/000/bvo00033/vsc11346/SPEI_R/7.Caracterizacion_sequia/SPEI-12/2.Outputs/Tocantins/ssp585/drought_metrics_tocantins_ssp585_MRI-ESM2-0.nc
#
#   Computing ensemble median — ssp585
#     Saved: /data/brussel/vo/000/bvo00033/vsc11346/SPEI_R/7.Caracterizacion_sequia/SPEI-12/2.Outputs/Tocantins/ssp585/drought_metrics_tocantins_ssp585_ensemble.nc
#
#   Ensemble summary — ssp585:
#     FREQUENCY: min=4.00, max=9.00, median=6.00
#     DURATION: min=12.00, max=74.00, median=27.50
#     SEVERITY: min=17.04, max=76.36, median=33.69
#
# ============================================================
# COMPLETED — Tocantins basin, 5 models, 3 scenarios
# Output: /data/brussel/vo/000/bvo00033/vsc11346/SPEI_R/7.Caracterizacion_sequia/SPEI-12/2.Outputs/Tocantins/
# ============================================================
# /tmp/ipykernel_715602/3043205760.py:205: RuntimeWarning: All-NaN slice encountered
#   freq_ensemble = np.nanmedian(np.stack(freq_stack, axis=0), axis=0)
# /tmp/ipykernel_715602/3043205760.py:206: RuntimeWarning: All-NaN slice encountered
#   dur_ensemble  = np.nanmedian(np.stack(dur_stack,  axis=0), axis=0)
# /tmp/ipykernel_715602/3043205760.py:207: RuntimeWarning: All-NaN slice encountered
#   sev_ensemble  = np.nanmedian(np.stack(sev_stack,  axis=0), axis=0)

# %%
# ============================================================================
# Verification — Tocantins basin
# ============================================================================

import numpy as np
import xarray as xr
from pathlib import Path

path_out  = "/data/brussel/vo/000/bvo00033/vsc11346/SPEI_R/7.Caracterizacion_sequia/SPEI-12/2.Outputs/Tocantins/"
models    = ["MPI-ESM1-2-HR", "UKESM1-0-LL", "GFDL-ESM4", "IPSL-CM6A-LR", "MRI-ESM2-0", "ensemble"]
scenarios = ["historical", "ssp126", "ssp585"]
basin     = "tocantins"

print("=" * 60)
print("NETCDF VERIFICATION — Tocantins basin")
print("=" * 60)

all_ok = True

for scenario in scenarios:
    print(f"\n--- {scenario.upper()} ---")
    for model in models:
        nc_file = Path(f"{path_out}{scenario}/drought_metrics_{basin}_{scenario}_{model}.nc")

        if not nc_file.exists():
            print(f"  ❌ MISSING: {nc_file.name}")
            all_ok = False
            continue

        ds   = xr.open_dataset(nc_file)
        freq = np.where(ds["frequency"].values == -9999, np.nan, ds["frequency"].values.astype(float))
        dur  = np.where(ds["duration"].values  == -9999, np.nan, ds["duration"].values.astype(float))
        sev  = np.where(ds["severity"].values  == -9999, np.nan, ds["severity"].values.astype(float))
        lon  = ds["lon"].values
        lat  = ds["lat"].values
        ds.close()

        n_valid      = np.sum(~np.isnan(freq))
        shape_ok     = freq.ndim == 2
        pixels_ok    = (np.sum(~np.isnan(freq)) == np.sum(~np.isnan(dur)) == np.sum(~np.isnan(sev)))
        values_ok    = (np.all(freq[~np.isnan(freq)] >= 0) and
                        np.all(dur[~np.isnan(dur)]   >= 0) and
                        np.all(sev[~np.isnan(sev)]   >= 0))
        no_inf       = not (np.any(np.isinf(freq)) or np.any(np.isinf(dur)) or np.any(np.isinf(sev)))

        status = "✅" if (shape_ok and pixels_ok and values_ok and no_inf) else "❌"
        if status == "❌":
            all_ok = False

        print(f"  {status} {model}")
        print(f"       Shape: {freq.shape} | Valid pixels: {n_valid} | "
              f"Freq=[{freq[~np.isnan(freq)].min():.1f},{freq[~np.isnan(freq)].max():.1f}] | "
              f"Dur=[{dur[~np.isnan(dur)].min():.1f},{dur[~np.isnan(dur)].max():.1f}] | "
              f"Sev=[{sev[~np.isnan(sev)].min():.2f},{sev[~np.isnan(sev)].max():.2f}]")

print(f"\n{'='*60}")
print("✅ ALL FILES VERIFIED" if all_ok else "❌ SOME FILES HAVE ISSUES")
print(f"{'='*60}")
# Out:
# ============================================================
# NETCDF VERIFICATION — Tocantins basin
# ============================================================
#
# --- HISTORICAL ---
#   ✅ MPI-ESM1-2-HR
#        Shape: (34, 32) | Valid pixels: 566 | Freq=[2.0,9.0] | Dur=[6.0,44.0] | Sev=[4.56,50.76]
#   ✅ UKESM1-0-LL
#        Shape: (34, 32) | Valid pixels: 566 | Freq=[3.0,10.0] | Dur=[5.5,44.0] | Sev=[4.23,45.81]
#   ✅ GFDL-ESM4
#        Shape: (34, 32) | Valid pixels: 566 | Freq=[3.0,8.0] | Dur=[11.0,36.5] | Sev=[8.62,44.98]
#   ✅ IPSL-CM6A-LR
#        Shape: (34, 32) | Valid pixels: 566 | Freq=[2.0,8.0] | Dur=[10.0,61.0] | Sev=[8.94,65.58]
#   ✅ MRI-ESM2-0
#        Shape: (34, 32) | Valid pixels: 566 | Freq=[2.0,9.0] | Dur=[12.0,126.0] | Sev=[6.95,111.22]
#   ✅ ensemble
#        Shape: (34, 32) | Valid pixels: 566 | Freq=[4.0,7.0] | Dur=[12.0,33.5] | Sev=[12.66,42.36]
#
# --- SSP126 ---
#   ✅ MPI-ESM1-2-HR
#        Shape: (34, 32) | Valid pixels: 566 | Freq=[3.0,10.0] | Dur=[11.0,36.0] | Sev=[10.68,47.79]
#   ✅ UKESM1-0-LL
#        Shape: (34, 32) | Valid pixels: 566 | Freq=[3.0,9.0] | Dur=[12.0,119.0] | Sev=[11.62,130.69]
#   ✅ GFDL-ESM4
#        Shape: (34, 32) | Valid pixels: 566 | Freq=[4.0,10.0] | Dur=[9.0,47.0] | Sev=[8.72,60.65]
#   ✅ IPSL-CM6A-LR
#        Shape: (34, 32) | Valid pixels: 566 | Freq=[4.0,10.0] | Dur=[8.0,47.0] | Sev=[7.05,51.04]
#   ✅ MRI-ESM2-0
#        Shape: (34, 32) | Valid pixels: 566 | Freq=[3.0,10.0] | Dur=[9.0,78.0] | Sev=[7.78,89.91]
#   ✅ ensemble
#        Shape: (34, 32) | Valid pixels: 566 | Freq=[4.0,9.0] | Dur=[12.0,37.0] | Sev=[14.97,47.58]
#
# --- SSP585 ---
#   ✅ MPI-ESM1-2-HR
#        Shape: (34, 32) | Valid pixels: 566 | Freq=[2.0,9.0] | Dur=[10.0,153.5] | Sev=[10.43,180.80]
#   ✅ UKESM1-0-LL
#        Shape: (34, 32) | Valid pixels: 566 | Freq=[2.0,8.0] | Dur=[12.0,174.5] | Sev=[13.67,190.75]
#   ✅ GFDL-ESM4
#        Shape: (34, 32) | Valid pixels: 566 | Freq=[4.0,11.0] | Dur=[11.0,89.0] | Sev=[13.00,96.84]
#   ✅ IPSL-CM6A-LR
#        Shape: (34, 32) | Valid pixels: 566 | Freq=[3.0,9.0] | Dur=[9.0,77.0] | Sev=[9.88,95.37]
#   ✅ MRI-ESM2-0
#        Shape: (34, 32) | Valid pixels: 566 | Freq=[2.0,11.0] | Dur=[11.0,147.5] | Sev=[11.55,167.61]
#   ✅ ensemble
#        Shape: (34, 32) | Valid pixels: 566 | Freq=[4.0,9.0] | Dur=[12.0,74.0] | Sev=[17.04,76.36]
#
# ============================================================
# ✅ ALL FILES VERIFIED
# ============================================================
